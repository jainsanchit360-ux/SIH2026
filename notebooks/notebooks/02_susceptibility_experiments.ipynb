# %% [markdown]
# # Notebook 02: Static Landslide Susceptibility Modeling Experiments
#
# **Project:** ResQtech - AI-Based Early Warning & Landslide Risk Monitoring System (NER India)
#
# ## Objectives:
# - Feature engineering: Extract elevation, slope, aspect, terrain curvature, and GSI proximity features.
# - Generate spatial background/control samples across NER study region.
# - Model baseline training: Random Forest classifier and Gradient Boosting benchmarks.
# - Model evaluation: Confusion Matrix, Precision, Recall, F1-score, ROC-AUC, and feature importance analysis.
