# %% [markdown]
# # Notebook 03: Dynamic Risk & Environmental Trigger Experiments
#
# **Project:** ResQtech - AI-Based Early Warning & Landslide Risk Monitoring System (NER India)
#
# ## Objectives:
# - Process NASA GPM IMERG rainfall rasters (1-day, 3-day, and 7-day cumulative rainfall).
# - Process NASA SMAP soil moisture products.
# - Compute dynamic environmental trigger index (0–100).
# - Implement Two-Layer Risk Fusion Engine combining static susceptibility and dynamic trigger scores into overall risk levels (LOW, MODERATE, HIGH).
